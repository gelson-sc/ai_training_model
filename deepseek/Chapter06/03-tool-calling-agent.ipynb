# %%
import os
from openai import OpenAI
import httpx

import inspect
from diskcache import Cache
from pydantic import BaseModel

from typing import Any
import jupyter_black
import requests
from markdownify import markdownify as md

jupyter_black.load()

DEEPSEEK_API_KEY = os.environ["DEEPSEEK_API_KEY"]
DEEPSEEK_BASE_URL = "https://api.deepseek.com"
MODEL = "deepseek-chat"
cache = Cache("./cache")
client = OpenAI(api_key=DEEPSEEK_API_KEY, base_url=DEEPSEEK_BASE_URL)

# %%
def to_openai_tool(func: callable) -> dict[str, Any]:
    sig = inspect.signature(func)
    if sig.parameters:
        param = next(iter(sig.parameters.values()))
        param_type = param.annotation
        schema = param_type.model_json_schema()
    else:
        param_type = None
        schema = {"type": "object", "properties": {}, "required": []}

    return {
        "type": "function",
        "function": {
            "name": func.__name__,
            "description": (param_type.__doc__ if param_type else func.__doc__ or ""),
            "parameters": schema,
        },
    }


@cache.memoize(expire=3600)
def llm_call(
    messages: list[dict[str, str]], tools: list[dict[str, Any]], model: str
) -> str:
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        tools=tools if tools else None,
        temperature=0.0,
        tool_choice="auto",
    )

    message = response.choices[0].message

    if hasattr(message, "reasoning_content"):
        del message.reasoning_content

    return message

# %%
class SearchWeb(BaseModel):
    """Search the web for a given query."""

    query: str
    max_results: int = 10


def search_web(data: SearchWeb) -> str:
    base_url = "https://api.marginalia.nu/{key}/search/{query}"
    url = base_url.format(key="public", query=data.query)
    url += f"?count={data.max_results}"

    rsp = httpx.get(url)
    rsp.raise_for_status()

    results = rsp.json()["results"]
    return str(results)


class ReadWebsite(BaseModel):
    """Read the content of a website and return it as text. (useful for further research)"""

    url: str


def read_website(data: ReadWebsite) -> str:

    html_content = requests.get(data.url).text
    return md(html_content)


TOOLS = [
    to_openai_tool(search_web),
    to_openai_tool(read_website),
]
FUNC_TYPES = {
    search_web: SearchWeb,
    read_website: ReadWebsite,
}

# %%
TOOLS
# Out:
# [{'type': 'function',
#   'function': {'name': 'search_web',
#    'description': 'Search the web for a given query.',
#    'parameters': {'description': 'Search the web for a given query.',
#     'properties': {'query': {'title': 'Query', 'type': 'string'},
#      'max_results': {'default': 10,
#       'title': 'Max Results',
#       'type': 'integer'}},
#     'required': ['query'],
#     'title': 'SearchWeb',
#     'type': 'object'}}},
#  {'type': 'function',
#   'function': {'name': 'read_website',
#    'description': 'Read the content of a website and return it as text. (useful for further research)',
#    'parameters': {'description': 'Read the content of a website and return it as text. (useful for further research)',
#     'properties': {'url': {'title': 'Url', 'type': 'string'}},
#     'required': ['url'],
#     'title': 'ReadWebsite',
#     'type': 'object'}}}]

# %%
print(search_web(SearchWeb(query="Paris", max_results=2)))
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Paris_Las_Vegas', 'title': 'Paris Las Vegas', 'description': 'Paris Las Vegas is a casino hotel on the Las Vegas Strip in Paradise, Nevada. It is owned and operated by Caesars Entertainment. Property features include a 95,263-square-foot (8,850.2 m casino, 2,916 hotel rooms, a 1,400-seat performance theater, and var', 'quality': 5.037784569660175, 'format': 'html', 'details': [[]]}, {'url': 'https://en.wikipedia.org/wiki/Paris_Observatory', 'title': 'Paris Observatory', 'description': 'The Paris Observatory (French Observatoire de Paris; French pronunciation bsɛʁvatwaʁ də paʁi a research institution of the Paris Sciences et Lettres University, is the foremost astronomical observatory of France, and one of the largest astronomical center', 'quality': 5.161455267002603, 'format': 'html', 'details': [[]]}]

# %%
print(read_website(data=ReadWebsite(url="https://www.theguardian.com/europe")))
# Out:
# Latest news, sport and opinion from the Guardian
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ![](https://sb.scorecardresearch.com/p?c1=2&c2=6035250&cv=2.0&cj=1&cs_ucfr=0&comscorekw=europe)
#
#
# [Skip to main content](#maincontent)[Skip to navigation](#navigation)
#
# [Print subscriptions](https://support.theguardian.com/subscribe/weekly?REFPVID=undefined&INTCMP=undefined&acquisitionData=%7B%22source%22%3A%22GUARDIAN_WEB%22%2C%22componentId%22%3A%22PrintSubscriptionsHeaderLink%22%2C%22componentType%22%3A%22ACQUISITIONS_HEADER%22%2C%22referrerUrl%22%3A%22%22%7D)
#
# [Search jobs](https://jobs.theguardian.com)
#
# [Sign in](https://profile.theguardian.com/signin?INTCMP=DOTCOM_NEWHEADER_SIGNIN&ABCMP=ab-sign-in&componentEventParams=componentType%3Didentityauthentication%26componentId%3Dguardian_signin_header)
#
# 1. ### Twelve days in Gaza What happened while the world looked away?
#
#    ![Relatives, including injured children, at a funeral in Gaza City on 24 June.](https://i.guim.co.uk/img/media/364349bae0e2c1c217c467b446d4ba044fbd87eb/520_657_4379_3503/master/4379.jpg?width=112&dpr=1&s=none&crop=1%3A1)
# 2. ### Rokhaya Diallo French cinema buries colonial crimes
#
#    ![Rokhaya Diallo](https://i.guim.co.uk/img/uploads/2023/05/17/Rokhaya_Diallo.png?width=150&dpr=1&s=none&crop=none)
# 3. ### Friendship The steps I took to beat loneliness in my 30s
#
#    ![Illustration of people chatting about books, cats, music](https://i.guim.co.uk/img/media/455d310a139fd885c242b084c4edb70f6be1f260/0_3_1677_2095/master/1677.jpg?width=112&dpr=1&s=none&crop=1%3A1)
# 4. ### Tour de France 50 years of finishes on the Champs-Élysées
#
#    ![Bernard Hinault and Greg LeMond lead the peloton on the Champs-Élysées during the final stage in 1986.](https://i.guim.co.uk/img/media/5d6c5e388fbbe4ead7afbc9739ca388cf0d8a1ef/1814_0_2856_3570/master/2856.jpg?width=112&dpr=1&s=none&crop=1%3A1)
# 5. ### Environment The French town that banned its tap water
#
#    ![Sandra Wiedemann, with baby Côme.](https://i.guim.co.uk/img/media/ae15a46d9c41b461690e3901907bd1e007e62bc1/106_1773_2342_2342/master/2342.jpg?width=112&dpr=1&s=none&crop=1%3A1)
# 6. ### The long read A dance with Putin spotlights Austria’s Russia ties
#
#    ![Karin Kneissl dances with Vladimir Putin at her wedding reception in Gamlitz, Austria, 18 August 2018](https://i.guim.co.uk/img/media/dac11407e002364d30778f28705ef1957da59d81/142_0_4178_3341/master/4178.jpg?width=112&dpr=1&s=none&crop=1%3A1)
#
# Eur
#
# * [Europe edition](/preference/edition/eur)
# * [UK edition](/preference/edition/uk)
# * [US edition](/preference/edition/us)
# * [Australia edition](/preference/edition/au)
# * [International edition](/preference/edition/int)
#
# [The Guardian - Back to homeThe Guardian](/)
#
# * [News](/)
# * [Opinion](/commentisfree)
# * [Sport](/sport)
# * [Culture](/culture)
# * [Lifestyle](/lifeandstyle)
#
# Show moreHide expanded menu
#
# * News
#   + [View all News](/)
#   + [World news](/world)
#   + [UK news](/uk-news)
#   + [Climate crisis](/environment/climate-crisis)
#   + [Ukraine](/world/ukraine)
#   + [Environment](/environment)
#   + [Science](/science)
#   + [Global development](/global-development)
#   + [Football](/football)
#   + [Tech](/technology)
#   + [Business](/business)
#   + [Obituaries](/obituaries)
# * Opinion
#   + [View all Opinion](/commentisfree)
#   + [The Guardian view](/profile/editorial)
#   + [Columnists](/index/contributors)
#   + [Cartoons](/tone/cartoons)
#   + [Opinion videos](/type/video+tone/comment)
#   + [Letters](/tone/letters)
# * Sport
#   + [View all Sport](/sport)
#   + [Football](/football)
#   + [Cricket](/sport/cricket)
#   + [Rugby union](/sport/rugby-union)
#   + [Tennis](/sport/tennis)
#   + [Cycling](/sport/cycling)
#   + [F1](/sport/formulaone)
#   + [Golf](/sport/golf)
#   + [US sports](/sport/us-sport)
# * Culture
#   + [View all Culture](/culture)
#   + [Books](/books)
#   + [Music](/music)
#   + [TV & radio](/tv-and-radio)
#   + [Art & design](/artanddesign)
#   + [Film](/film)
#   + [Games](/games)
#   + [Classical](/music/classicalmusicandopera)
#   + [Stage](/stage)
# * Lifestyle
#   + [View all Lifestyle](/lifeandstyle)
#   + [Fashion](/fashion)
#   + [Food](/food)
#   + [Recipes](/tone/recipes)
#   + [Love & sex](/lifeandstyle/love-and-sex)
#   + [Health & fitness](/lifeandstyle/health-and-wellbeing)
#   + [Home & garden](/lifeandstyle/home-and-garden)
#   + [Women](/lifeandstyle/women)
#   + [Men](/lifeandstyle/men)
#   + [Family](/lifeandstyle/family)
#   + [Travel](/travel)
#   + [Money](/money)
# * Search input
#
#   google-search
#
#   Search
#
# + [Support us](https://support.theguardian.com?INTCMP=side_menu_support&acquisitionData=%7B%22source%22:%22GUARDIAN_WEB%22,%22componentType%22:%22ACQUISITIONS_HEADER%22,%22componentId%22:%22side_menu_support%22%7D)
# + [Print subscriptions](https://support.theguardian.com/subscribe/weekly?REFPVID=undefined&INTCMP=undefined&acquisitionData=%7B%22source%22%3A%22GUARDIAN_WEB%22%2C%22componentId%22%3A%22PrintSubscriptionsHeaderLink%22%2C%22componentType%22%3A%22ACQUISITIONS_HEADER%22%2C%22referrerUrl%22%3A%22%22%7D)
#
# * + [Search jobs](https://jobs.theguardian.com)
#   + [Holidays](https://holidays.theguardian.com?INTCMP=holidays_int_web_newheader)
#   + [Digital Archive](https://theguardian.newspapers.com)
#   + [Guardian Licensing](https://licensing.theguardian.com/)
#   + [About Us](/about)
#   + [The Guardian app](https://app.adjust.com/16xt6hai)
#   + [Video](/video)
#   + [Podcasts](/podcasts)
#   + [Pictures](/inpictures)
#   + [Newsletters](/email-newsletters)
#   + [Today's paper](/theguardian)
#   + [Inside the Guardian](https://www.theguardian.com/insidetheguardian)
#   + [Guardian Weekly](https://www.theguardian.com/weekly?INTCMP=gdnwb_mawns_editorial_gweekly_GW_TopNav_Int)
#   + [Crosswords](/crosswords)
#   + [Wordiply](https://www.wordiply.com)
#   + [Corrections](/theguardian/series/corrections-and-clarifications)
#   + [Tips](https://www.theguardian.com/tips)
# * Search input
#
#   google-search
#
#   Search
#
#   + [Search jobs](https://jobs.theguardian.com)
#   + [Holidays](https://holidays.theguardian.com?INTCMP=holidays_int_web_newheader)
#   + [Digital Archive](https://theguardian.newspapers.com)
#   + [Guardian Licensing](https://licensing.theguardian.com/)
#   + [About Us](/about)
#
# * [World](/world)
# * [UK](/uk-news)
# * [Climate crisis](/environment/climate-crisis)
# * [Ukraine](/world/ukraine)
# * [Environment](/environment)
# * [Science](/science)
# * [Global development](/global-development)
# * [Football](/football)
# * [Tech](/technology)
# * [Business](/business)
# * [Obituaries](/obituaries)
#
# News
# ----
#
# Hide
#
# * + ![Paris is on red alert for high temperatures](https://i.guim.co.uk/img/media/08decd9818214da5ae7aeb246066e2c78928ad66/963_0_4817_3855/master/4817.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#     Paris is on red alert for high temperatures
#   + ![Heatwave expected to last at least until midweek in Paris](https://i.guim.co.uk/img/media/2cac94c2a5706e85b4aa62b8bdf66ca73737e9f3/326_0_3340_2672/master/3340.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#     Heatwave expected to last at least until midweek in Paris
#   + ![Two people cool off in London ](https://i.guim.co.uk/img/media/7f5d85d6dc3f502b0c84669e2edf0890ebb93417/173_0_3333_2668/master/3333.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#     Two people cool off in London
#   + ![Firefighting efforts continue in Hatay's Antakya district](https://i.guim.co.uk/img/media/d24ba376a3fa623878ef0bfe774276cb6f81b024/0_0_5800_4640/master/5800.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#     Firefighting efforts continue in Hatay's Antakya district
#   + ![People sunbathe in the Jardin du Luxembourg as a heatwave hits Europe](https://i.guim.co.uk/img/media/8aeed3fbb68b01ae74a6747e7f92635a237074e1/883_0_5000_4000/master/5000.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#     People sunbathe in the Jardin du Luxembourg as a heatwave hits Europe
#
#   ### Europe live Paris on red alert as Europe faces extreme heat with weather warnings in place across continent
#
#   Public health warnings as heatwave raises concerns about impact of climate change
#
#   22m ago
#
#   + [### Explained The ‘silent killer’: what you need to know about heatwaves](/environment/2025/jun/27/the-silent-killer-what-you-need-to-know-about-heatwaves)
#   + [### Extreme heat Spain records highs of 46C and France under alert as Europe swelters in heatwave](/environment/2025/jun/30/spain-records-highs-of-46c-and-france-under-alert-as-europe-swelters-in-heatwave)
#   + [### In pictures Europe swelters under heatwave](/world/gallery/2025/jun/30/europe-swelters-under-heatwave-in-pictures)
#
#   + [### Explained The ‘silent killer’: what you need to know about heatwaves](/environment/2025/jun/27/the-silent-killer-what-you-need-to-know-about-heatwaves)
#   + [### Extreme heat Spain records highs of 46C and France under alert as Europe swelters in heatwave](/environment/2025/jun/30/spain-records-highs-of-46c-and-france-under-alert-as-europe-swelters-in-heatwave)
#   + [### In pictures Europe swelters under heatwave](/world/gallery/2025/jun/30/europe-swelters-under-heatwave-in-pictures)
#
# * ![Aerial view of rainforest in Amazonas state, Brazil, as the sun hangs low over the river](https://i.guim.co.uk/img/media/8b0dee63fbd69a13866ea0f624a96ddd529914b3/958_0_5483_4387/master/5483.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### Exclusive EU may allow carbon credits from developing countries to count towards climate goals
#
#   Green groups furious at plans to let member states buy controversial carbon offsets from overseas
#
#   2h ago
#
# * ![Demonstrators clash with anti-riot police in Istanbul after gathering over a cartoon allegedly of the prophet Muhammad](https://i.guim.co.uk/img/media/47b8319dd5200d0385430e8d63076fa8186ef92a/326_0_3750_3000/master/3750.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### Turkey Clashes and arrests in Turkey over magazine cartoon allegedly depicting prophet Muhammad
#
#   9h ago
# * ![The Countess of Chester hospital](https://i.guim.co.uk/img/media/bde90d57ae9a4751139b90098cb328ff5b7a44b0/289_0_4256_3405/master/4256.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### UK Three bosses at Lucy Letby hospital arrested on suspicion of manslaughter
#
#   2h ago
#
# * ![Performers stand on stage as North Korean Leader Kim Jong Un draping coffins with the North Korean flag is displayed on a screen, in Pyongyang, North Korea, June 29, 2025, in this still image taken from a video.  KRT/via REUTERS    THIS IMAGE HAS BEEN SUPPLIED BY A THIRD PARTY. NORTH KOREA OUT. NO COMMERCIAL OR EDITORIAL SALES INNORTH KOREA](https://i.guim.co.uk/img/media/0015203f97ab29a6b2b02c082a0937e85cf352f9/570_0_2690_2153/master/2690.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### North Korea Kim Jong-un pays rare public tribute to North Korean soldiers killed in Ukraine
#
#   8h ago
#
#   + [### Ukraine briefing Russia claims to have seized all of Luhansk region](/world/2025/jul/01/ukraine-war-briefing-russia-claims-to-have-seized-all-of-luhansk-region-and-first-village-in-dnipropetrovsk)
# * ![A Palestinian man carries the shrouded body of a relative, apparently a child, killed in the Israeli strike on al-Baqa cafe.](https://i.guim.co.uk/img/media/9eeb3b916a56936ac3075e0cd063bfc8ea05f5cd/0_0_6831_5464/master/6831.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### Gaza Witnesses describe grim aftermath of Israeli strike on busy Gaza cafe
#
#   3h ago
#
#   + [### Middle East Israel launches waves of Gaza airstrikes after new displacement orders](/world/2025/jun/30/israel-launches-waves-of-gaza-airstrikes-after-new-displacement-orders)
#
# * ![Senate staffers rest on the US Capitol steps at sunrise as Republican lawmakers struggle to pass Trump’s spending bill.](https://i.guim.co.uk/img/media/36035efd7e8ee0d41858db0c9865a009b60a0756/0_0_5000_4000/master/5000.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### US politics live Marathon vote on Trump’s ‘big, beautiful bill’ continues as ‘vote-a-rama’ becomes longest in Senate history
#
#   5m ago
#
#   + [### Elon Musk Musk vows to unseat lawmakers who support Trump’s ‘big beautiful bill’](/technology/2025/jun/30/musk-big-beautiful-bill-america-party)
# * ![A prison officer walks down a corridor in a jail](https://i.guim.co.uk/img/media/36b64fbfddf5d0769a50bfbfe1770106d35fe2c7/271_0_2134_1707/master/2134.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ###
jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### France ‘A supermarket for sexual predators’: abuse scandal at elite boarding school shakes France
#
#   8h ago
# * ![a man dancing](https://i.guim.co.uk/img/media/5a9eff262e845eddb66f66af8c6dfbfe018abf29/520_0_5200_4160/master/5200.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### Canada After 150 years, a prized box returns to an Indigenous nation in Canada: ‘I felt like royalty traveling with it’
#
#   16m ago
#
# Features
# --------
#
# Hide
#
# * ![Bernard Hinault and Greg LeMond lead the peloton on the Champs-Élysées during the final stage in 1986.](https://i.guim.co.uk/img/media/5d6c5e388fbbe4ead7afbc9739ca388cf0d8a1ef/1814_0_2856_3570/master/2856.jpg?width=465&dpr=1&s=none&crop=4%3A5)
#
#   ### Tour de France Quel triomphe! Tour de France celebrates 50 years of finishes on Champs-Élysées
#
#   5h ago
# * ![Illustration of people chatting about books, cats, music](https://i.guim.co.uk/img/media/455d310a139fd885c242b084c4edb70f6be1f260/0_3_1677_2095/master/1677.jpg?width=465&dpr=1&s=none&crop=4%3A5)
#
#   ### Friendship I was getting lonely. Here’s what happened when I tried to make new friends in my 30s
#
#   3h ago[…
#
#   …
#
#    comments](/lifeandstyle/2025/jul/01/adult-loneliness-making-friends-as-a-grown-up#comments)
#
# More features
# -------------
#
# Hide
#
# * ![Three young men wearing shorts, T-shirts and hats, standing among some seated camels](https://i.guim.co.uk/img/media/b599f3fee9795a4a21b58810a221cbfa253ba0e1/0_800_4176_3339/master/4176.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### Travel How three young Londoners set out to explore the countries of their parents’ birth – and redefined the travel vlog
#
#   6h ago
# * ![Dorian Lynskey](https://i.guim.co.uk/img/uploads/2018/08/30/Dorian_Lynskey,_L.png?width=80&dpr=1&s=none&crop=none)
#
#   ### What would British culture be like if Oasis had never existed?
#
#   Dorian Lynskey
#
#   2h ago
#
# * ![Manuela Giugliano, Aggie Beever-Jones, Claudia Pina, a Dutch superfan.](https://i.guim.co.uk/img/media/0c884810d9057f10948203bd8e70578824756dd4/0_0_2500_2000/master/2500.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### Football Women’s Euro 2025: Guardian writers’ predictions for the tournament
#
#   1h ago
# * ![Life is Beautiful. Directed by Mohamed Jabaly](https://i.guim.co.uk/img/media/b5e247080990616713302d3bf3d4efc852882703/1271_39_5428_4343/master/5428.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### Film Life Is Beautiful review – poignantly upbeat journal of a Gazan exile stranded in Norway
#
#   2h ago
#
# * ![She sits on the pebbles, looking at the camera](https://i.guim.co.uk/img/media/c7bf8883274569d58fda8461c8db45a9dae77d5d/626_666_4296_3437/master/4296.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### Work ‘My mind was shrieking: “What am I doing?”’ – when the digital nomad dream turns sour
#
#   8h ago
# * ![Women in elaborate, brightly coloured dresses with long flowing hair and dramatic makeup dance at the opening ceremony.](https://i.guim.co.uk/img/media/1bcf6f9970d2a403bf89791c0fb28604e23c8469/290_60_2282_1825/master/2282.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### Theatre Shakespeare in war: bard’s ‘existential’ theatre takes hold in Ukraine
#
#   5h ago
#
# [Opinion
# -------](https://www.theguardian.com/uk/commentisfree)
#
# Hide
#
# * ![Hassan Abo Qamar](https://i.guim.co.uk/img/uploads/2025/06/30/Hassan_Abo_Qamar.png?width=150&dpr=1&s=none&crop=none)
#
#   ### In Gaza we watched Iranian missiles go by, heading for Israel. That war is over – it seems ours will never end
#
#   Hassan Abo Qamar
#
#   For two years, we’ve waited for a final ceasefire that has never come. Peace will be delayed as long as our lives are considered disposable, says Hassan Abo Qamar, a Palestinian writer and journalist based in Gaza
#
#   2h ago
#
# * ![Rokhaya Diallo](https://i.guim.co.uk/img/uploads/2023/05/17/Rokhaya_Diallo.png?width=150&dpr=1&s=none&crop=none)
#
#   ### I learned about slavery from Hollywood. Why is French cinema so slow to depict our own colonial crimes?
#
#   Rokhaya Diallo
#
#   A biopic of Frantz Fanon and other remarkable new movies are finding success via social media, yet remain invisible at the big film festivals
#
#   8h ago
#
# More opinion
# ------------
#
# Hide
#
# 1. ![Arwa Mahdawi](https://i.guim.co.uk/img/uploads/2017/10/06/Arwa_Mahdawi,_L.png?width=80&dpr=1&s=none&crop=none)
#
#    ### I can’t believe I need to spell this out – but Trump is not your daddy
#
#    Arwa Mahdawi
#
#    41m ago[…
#
#    …
#
#     comments](/commentisfree/2025/jul/01/i-cant-believe-i-need-to-spell-this-out-but-trump-is-not-your-daddy#comments)
# 2. ![Juliet Stevenson](https://i.guim.co.uk/img/uploads/2025/06/30/Juliet_Stevenson.png?width=80&dpr=1&s=none&crop=none)
#
#    ### Palestine Action spraying paint is not terrorism. As ministers abuse their powers, I feel a duty to speak out
#
#    Juliet Stevenson
# 3. ![Eamonn Forde](https://i.guim.co.uk/img/uploads/2022/04/26/Eamonn_Forde.png?width=80&dpr=1&s=none&crop=none)
#
#    ### It’s not inevitable that musical dinosaurs dominate the charts. Here’s how we rescue pop in Britain
#
#    Eamonn Forde
#
#    5h ago[…
#
#    …
#
#     comments](/commentisfree/2025/jul/01/musical-dinosaurs-charts-rescue-pop-britain-australia-streaming#comments)
# 4. ### I’m not ignoring your message – I’m overwhelmed by the tyranny of being reachable
#
#    Miski Omar
#
#    9h ago[…
#
#    …
#
#     comments](/commentisfree/2025/jul/01/im-not-ignoring-your-message-im-overwhelmed-by-the-tyranny-of-being-reachable#comments)
#
# [Sport
# -----](https://www.theguardian.com/uk/sport)
#
# Hide
#
# * ![Jannik Sinner of Italy looks on ahead of his match against Luca Nardi of Italy.](https://i.guim.co.uk/img/media/8937be5c37efc768e171429fc8f42f2a9323aaf7/907_170_4093_3275/master/4093.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### Tennis live Wimbledon 2025 – Sinner and Zheng in action; Pegula crashes out as temperature soars
#
#   More big names enter the fray in SW19 on day two. Join our writers for all the action
#
#   now
#
#   + [### Brit-watch Boulter rounds off Britain’s opening day in the sun at SW19](/sport/2025/jun/30/british-players-wimbledon-day-one-tennis-sonay-kartal-jelena-ostsapenko-tennis)
#   + [### Women's singles Raducanu too strong for teenager Xu in all-British battle](/sport/2025/jun/30/emma-raducanu-too-strong-for-teenager-mimi-xu-in-british-battle)
#   + [### Men's singles British world No 733 Tarvet conjures shock to tee up Alcaraz clash](/sport/2025/jun/30/british-world-no-733-tarvet-conjures-wimbledon-shock-to-tee-up-potential-alcaraz-clash)
jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#    ### Environment How Indigenous people find themselves on the frontline of the green transition
#
#    4h ago
# 3. ![A man sits at a table in front of a microscope in a laboratory. Another microscope is also on the table](https://i.guim.co.uk/img/media/2b0f6cf7068b069066ba98e19e511212c622e86d/1068_239_3877_3101/master/3877.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#    ### Why I'm obsessed with ... Brittle stars: fish often nip off bits of their arms but they regenerate
# 4. ![an oil pumpjack is silhouetted](https://i.guim.co.uk/img/media/ff053214f27609daa3e3ee71ed778ec485e2f828/666_0_3334_2667/master/3334.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#    ### Climate crisis UN expert urges criminalising fossil fuel disinformation, banning lobbying
#
# [More UK news
# ------------](https://www.theguardian.com/uk-news)
#
# Hide
#
# 1. ### BBC UK’s chief rabbi says Bob Vylan Glastonbury chant was ‘vile Jew-hatred’
#
#    4h ago
# 2. ### UK Royal train to be retired as King Charles seeks to modernise monarchy
# 3. ### Business Sainsbury’s boss warns over retail taxes after ‘high impact’ NI rise
#
#    3h ago
# 4. ### India Meet Kerala’s ‘rainforest gardeners’ creating a Noah’s ark for endangered plants
#
#    5h ago
#
# [More world news
# ---------------](https://www.theguardian.com/world)
#
# Hide
#
# 1. ### Gambling Norway lottery operator apologises to 47,000 players over prize mixup
# 2. ### US Obama calls Trump’s USAID closure a ‘travesty’ as report warns of extra 14 million deaths by 2030
#
#    1h ago
# 3. ### Southern frontlines Brazil’s last asbestos miners are switching to rare earth minerals. Can they offer a brighter future?
#
#    3h ago
# 4. ### India Prada accused of cashing in on Indian culture with Kolhapuri-inspired sandals
#
# [Tip us off
#
# Share stories with the Guardian securely and confidentially](https://theguardian.com/tips)
#
# [Culture
# -------](https://www.theguardian.com/uk/culture)
#
# Hide
#
# * ![MYERS,CARVEY, WAYNE'S WORLD 2, 1993<br>2JD8C0D MYERS,CARVEY, WAYNE'S WORLD 2, 1993](https://i.guim.co.uk/img/media/b3a3cdc2e31768dc38df059ebc726bc58e9c7567/91_0_2318_1855/master/2318.jpg?width=465&dpr=1&s=none&crop=4%3A5)
#
#   ### Film Austin Powers? The Godfather? Wild Things? Our writers on the franchises they would like to revive
#
#   3h ago[…
#
#   …
#
#    comments](/film/2025/jul/01/austin-powers-species-wild-things-our-writers-on-the-franchises-they-would-like-to-revive#comments)
# * ![Exodus, directed by Serkan Nihat](https://i.guim.co.uk/img/media/ab47eaa343b339af384409636cf7b434f658f3c6/649_287_2313_1851/master/2313.jpg?width=465&dpr=1&s=none&crop=4%3A5)
#
#   ### Film Exodus review – broadside against Erdoğan’s Turkey takes the multi-narrative, multi-character route
#
#   6h ago
#
# What to watch
# -------------
#
# Hide
#
# 1. ![Paul Walker as Brian O’Conner in Furious 7.](https://i.guim.co.uk/img/media/a72e340314d573bf22043dcf46e41b93a4985f45/850_0_1900_1521/master/1900.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#    ###
jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#    ### Fragrance ‘Smellmaxxing’ and ‘frag heads’: how the gen Z perfume boom came up roses for indie brands
# 2. ![Still life shoot for feature on Boobs for Saturday magazine. Food styling: Jack Sargeson](https://i.guim.co.uk/img/media/824cb41a115c1c08fe0b2d1f3d243d55ae6b5fc6/0_1055_4720_3777/master/4720.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#    ### Life and style Why gravity-defying boobs are back – and what they say about the state of the world
# 3. ![Model wearing waistcoat and baggy flared trousers](https://i.guim.co.uk/img/media/a1acbbd47f23a692e9eb19a3ca53671e2a55e773/0_0_5000_4000/master/5000.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#    ### Jess Cartner-Morley on fashion Forget Kate Moss at Glastonbury, the 2025 waistcoat is for everyone
#
#    […
#
#    …
#
#     comments](/fashion/2025/jun/27/jess-cartner-morley-on-fashion-forget-kate-moss-at-glastonbury-the-2025-waistcoat-is-for-everyone#comments)
# 4. ![An illustration of a woman with dotted lines on her face indicating where a procedure will be performed](https://i.guim.co.uk/img/media/f375720da6f03a97274325d3c44a25998b3d69d9/0_0_2997_2401/master/2997.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#    ### Well actually What is a deep plane facelift? Nipping into the buzzy cosmetic procedure
#
# [Relationships
# -------------](https://www.theguardian.com/lifeandstyle/love-and-sex)
#
# Hide
#
# 1. ![Composite image of a man sitting on an unmade bed in black and white, with a pink filter and white and red circles overlaid on the figure and background](https://i.guim.co.uk/img/media/d8424c3a6b4a41c1534897c4080318127ef3a327/0_0_6667_5333/master/6667.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### Sexual healing My girlfriend told me she prefers big penises. Now I’m worried I won’t satisfy her
#
#    3h ago
# 2. ![A woman sitting in a lounge chair at home relaxing with her eyes closed. She is holding a hot drink and listening to music on headphones.](https://i.guim.co.uk/img/media/c4974fd3de0729e51224a81b53aaa6ea11fd6db1/0_0_1890_1512/master/1890.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### How to build a better life I do not need an expensive hairbrush. So why have I spent so long fantasising about one?
# 3. ![A close-up of Keira Alexandra Kronvold](https://i.guim.co.uk/img/media/6c3f0dd39e5dc77dad404f2fec855994ed41cf35/0_662_3555_2844/master/3555.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### Parenting How a controversial Danish ‘parenting test’ separated a Greenlandic woman from her children
# 4. ![This is how we do it, 28 June](https://i.guim.co.uk/img/media/f348c56c9cc68ad603ac27be7e43e3d0d60fbc25/0_0_2000_1600/master/2000.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### This is how we do it Even after 11 years we have sex every day, and three times isn’t unusual
#
# [Health & fitness
# ----------------](https://www.theguardian.com/lifeandstyle/health-and-wellbeing)
#
# Hide
#
# 1. ![Caroline Butterwick standing next to a tree in a verdant space](https://i.guim.co.uk/img/media/01413604601f55a201aa809def15af6d2df02546/0_0_2419_3024/master/2419.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### The one change that worked Lonely and losing confidence, I was saved by an open-mic night
# 2. ![Illustration of a woman scowling at a hunk of cheese, who has arms, legs and a face as is giving her two V signs](https://i.guim.co.uk/img/media/2b5dbd6ec43a14cb5fcd0c4cd73b9142092b80a5/364_0_2126_1701/master/2126.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### Is it true that … … we’re all a little bit intolerant to dairy?
# 3. ![Gold-foil wrapeed chocolate bar floating and in spotlight](https://i.guim.co.uk/img/media/21f6573c08a6e6e56555f5709c95ae1435ef4493/0_3180_7832_6266/master/7832.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### Diets Healthy chocolate, low-hangover wine and nutritious breakfast cereal: 10 guilty pleasures … without the guilt
# 4. ![Composite of a woman studying a juice bottle, surrounded by fruit and veg](https://i.guim.co.uk/img/media/427371c812dd56b2977aa6ac707a24cc532ef46d/1122_0_3200_4000/master/3200.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### Health The truth about fruit juice and smoothies: should you down them or ditch them?
#
# More lifestyle
# --------------
#
# Hide
#
# 1. ![A chaotic illustration of various activities and objects, including young people dancing, drinking, playing video games, traveling, reading, walking dogs, and engaging in creative or leisure pursuits, all clustered together in a dynamic, swirling composition.](https://i.guim.co.uk/img/media/568bc4d5101368448239ff7083d07335368434fa/1_0_3599_2880/master/3599.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#    ### Money How gen Z is rewriting money rules: ‘I thrift, I splurge, I save 25%’
# 2. ![one person shaking hands with another person as their silhouette fades into pixels and other tech symbols](https://i.guim.co.uk/img/media/92fa873e0ee54c7d44aea4b39dc13f227b8e3ae4/283_0_2400_3000/master/2400.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#    ### Well actually ‘Hey man, I’m so sorry for your loss’: should you use AI to text?
# 3. ![Post-impressionist style illustration of a woman reading Infinite Jest at a table](https://i.guim.co.uk/img/media/67b9332ab3f648dfbbebb6f7f42386fd13cfd979/0_0_3000_2400/master/3000.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#    ### Books Is it OK to read Infinite Jest in public? Why the internet hates ‘performative reading’
#
#    […
#
#    …
#
#     comments](/lifeandstyle/2025/jun/30/performative-reading-public-tiktok#comments)
# 4. ![View of one of the lakes of Sierra de la Demanda, with a low mountain range behind](https://i.guim.co.uk/img/media/53e7cbfb4230f1ba9a14c432299cb82653a309b8/2155_0_2696_3370/master/2696.jpg?width=465&dpr=1&s=none&crop=5%3A4)
#
#    ### Travel Discovering Spain’s Sierra de la Demanda: the land that social media forgot
#
# [Documentary
# -----------](https://www.theguardian.com/documentaries)
#
# Hide
#
# * ![The cost of spiritual healing in the Amazon](https://i.guim.co.uk/img/media/0846ec1788f61341dbd91c052122da40b691e381/84_381_2224_1779/master/2224.jpg?width=465&dpr=1&s=none&crop=4%3A5)
#
#   Waska
#
#   ### The cost of spiritual healing in the Amazon
#
#   “Ayahuasca”: a mystical shortcut to healing and enlightenment, or commodification of the Amazon?
#
#   Video15:06
#
#   + [### Nina Gualinga and Eli Virkina ‘Ayahuasca tourism’ is a blight on Indigenous peoples and our environment](/commentisfree/2025/jun/17/ayahuasca-tourism-indigenous-peoples-environment-pyschedelics-biodiversity-ecuador)
#
# You may have missed
# -------------------
#
# Hide
#
# 1. ![DSC05799
#    Women survivors Tigray, Ethiopia
#    X-ray image showing a nail clipper inserted inside a uterus, Mekele, Tigray, March 2025.](https://i.guim.co.uk/img/media/5fc8d84636e77fc5f03f56c581e882ecc8f8129a/717_0_5000_4000/master/5000.jpg?width=465&dpr=1&s=none&crop=4%3A5)
#
#    ### Ethiopia Rusted screws, metal spikes and plastic rubbish: the horrific sexual violence used against Tigray’s women
# 2. ![a woman swinging through the air as a crowd watches](https://i.guim.co.uk/img/media/e49ca910dd0ef361175407b5b9146faf9735932a/309_0_2079_1663/master/2079.jpg?width=465&dpr=1&s=none&crop=4%3A5)
#
#    ### Ireland ‘Swashbuckling and cheeky’: island festival celebrates Ireland’s ‘pirate queen’
# 3. ![Illustration of a red figure and blue figure, both naked, lounging next to each other next to apples](https://i.guim.co.uk/img/media/d678a5e10e69211fbb0a333363db66b54d64fe21/0_0_2399_3000/master/2399.jpg?width=465&dpr=1&s=none&crop=4%3A5)
#
#    ### The featured essay A generation of ‘virgins’ is leading America’s next sexual revolution
#
# Take part
# ---------
#
# Hide
#
# 1. ![What have you always wondered about children and smartphones? ](https://i.guim.co.uk/img/media/f71abfc1bef5b1e6cf24d003f083cc13e655a894/1078_531_4217_2530/master/4217.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### Smartphones What questions do you have about the impacts of smartphones on children?
# 2. ![People sunbathing on Costa da Caparica beach in Almada, near Lisbon, during the first heatwave of the year on 29 June 2025.](https://i.guim.co.uk/img/media/df096aeb9f1952585b8823918172912c22b1b4c7/561_0_5613_4491/master/5613.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### Europe How are you being affected by the heatwave in southern Europe?
# 3. ![Emergency personnel work at an impact site following a missile attack from Iran on Israel, in Tel Aviv, Israel.](https://i.guim.co.uk/img/media/0ea504cacf30ad363e185b76497decebd5a56384/0_0_3230_2587/master/3230.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### Israel Living in Israel: how have you been affected by the recent conflict?
# 4. ![Smoke rises from an oil refinery north-west of Tehran, Iran.](https://i.guim.co.uk/img/media/ef6d00b20b11c1791bcde3f43ab1668ad577934e/144_426_3700_2960/master/3700.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### Iran Living in Iran: how have you been affected by the recent conflict?
#
# [Newsletters
# -----------](https://www.theguardian.com/email-newsletters)
#
# Hide
#
# 1. ![First Edition](https://i.guim.co.uk/img/media/1296f6c00eb025aed12539235dcd2a08515643c7/0_0_5000_3000/master/5000.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### News Sign up for the First Edition newsletter
#
#    Newsletter
# 2. ![Diaspora newsletter image](https://i.guim.co.uk/img/media/b6a94daec91cdc24e670ce2ace37383b27bce5d6/0_0_5000_3000/master/5000.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### Culture Sign up for The Long Wave newsletter: our weekly Black life and culture email
#
#    Newsletter
# 3. ![Feast](https://i.guim.co.uk/img/media/0edfd4ddd15717271a97f651cd955949b153b31b/0_0_5000_3000/master/5000.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### Food Sign up for the Feast newsletter
#
#    Newsletter
# 4. ![Football Daily sign up page](https://i.guim.co.uk/img/media/513d45c136273d89f0c4a831b7aba27fd761d10c/0_0_5000_3000/master/5000.jpg?width=120&dpr=1&s=none&crop=5%3A4)
#
#    ### Football Sign up for the Football Daily newsletter
#
#    Newsletter
#
# [In pictures
# -----------](https://www.theguardian.com/inpictures)
#
# Hide
#
# * ![People parade during the National Commemoration of Slavery (Keti Koti) in Amsterdam, the Netherlands](https://i.guim.co.uk/img/media/519df19bb10a8dde3cfcb82314036609d7381aea/0_0_5000_4000/master/5000.png?width=465&dpr=1&s=none&crop=5%3A4)
#
#   ### Photos of the day A freedom from slavery parade, heatwave and a fashion show
# %%
class Agent:
    def __init__(
        self,
        model: str,
        system: str,
        tools: list[dict[str, Any]] | None = None,
        max_iters: int = 10,
    ):
        self.model = model
        self.tools = tools or []
        self.messages: list[dict[str, str]] = []
        if system:
            self.messages.append({"role": "system", "content": system})

        self.max_iters = max_iters

    def __call__(self, content: str, verbose: bool) -> str:
        self.messages.append({"role": "user", "content": content})

        iterations = 0
        while True:
            iterations += 1
            message = self._send()
            self.messages.append(message)

            tool_calls = getattr(message, "tool_calls", None)
            if not tool_calls:
                return message.content

            for call in tool_calls:
                func = globals()[call.function.name]
                args_model = FUNC_TYPES[func]
                args = (
                    args_model.model_validate_json(call.function.arguments)
                    if call.function.arguments != "{}"
                    else None
                )
                print(f"** CALLING FUNCTION {func.__name__} **")
                print(f"*** ARGS ***\n{args}\n")

                result = func(args) if args else func()

                if verbose is True:
                    print(f"*** RESULT ***\n{result}\n***")

                self.messages.append(
                    {
                        "role": "tool",
                        "tool_call_id": call.id,
                        "content": result,
                    }
                )

            if iterations >= self.max_iters:
                raise Exception("Max iterations reached")

    def _send(self):
        return llm_call(self.messages, self.tools, self.model)

# %%
system_prompt = """
You are a helpful assistant who can answer multistep questions by sequentially calling functions. 

Follow a pattern of:
- THOUGHT (reason step-by-step about which function to call next)
- ACTION (call a function as a next step towards the final answer) 
- OBSERVATION (output of the function)

Reason step by step which actions to take to get to the answer. 

Only call functions with arguments coming verbatim from the user or the output of other functions.
"""

question = "What is the population of the city of Ancona as of 2025?"

# %%
bot = Agent(system=system_prompt, tools=TOOLS, model="deepseek-chat")
response = bot(question, verbose=False)
print("Response:", response)
# Out:
# ** CALLING FUNCTION search_web **
# *** ARGS ***
# query='population of Ancona Italy 2025' max_results=10
#
# ** CALLING FUNCTION read_website **
# *** ARGS ***
# url='https://population.city/italy/ancona/'
#
# Response: The last known population of Ancona, Italy, was approximately **101,500** in 2014. If the population growth rate remained consistent at **0.34% per year** (as observed between 2011-2014), the estimated population of Ancona in 2025 would be **105,351**.
#
# This is an unofficial projection based on historical data. For the most accurate and up-to-date figures, official census data or reports from the Italian National Institute of Statistics (ISTAT) would be required.

# %%
bot = Agent(system=system_prompt, tools=TOOLS, model="deepseek-reasoner")
response = bot(question, verbose=False)
print("Response:", response)
# Out:
# ** CALLING FUNCTION search_web **
# *** ARGS ***
# query='Ancona population 2025 projection' max_results=10
#
# ** CALLING FUNCTION search_web **
# *** ARGS ***
# query='Ancona Italy population 2025 official estimate' max_results=10
#
# ** CALLING FUNCTION read_website **
# *** ARGS ***
# url='https://www.citypopulation.de/en/italy/cities/marche/'
#
# Response: Based on the official population estimates from the Istituto Nazionale di Statistica Italia (Italy's National Institute of Statistics), the population of Ancona as of January 1, 2025 is **99,469**.
#
# This information comes directly from the detailed city and commune population tables on citypopulation.de, which sources its data from Italy's official statistics agency. The table shows:
# - 2021 census: 98,402
# - 2025 estimate: 99,469
#
# The population estimate represents the projected population for the city proper of Ancona as of the beginning of 2025.
